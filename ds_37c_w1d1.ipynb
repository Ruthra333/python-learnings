# %% [markdown]
# started exploring

# %%
a=2
#inside cell also we can write comment using #

# %%
var1=10

# %%
var2=20
var3=30

# %%
var1 ,var2 ,var3
# Out:
# 30

# %%
print(var1,var2)
print (var1)
print (var3)
# Out:
# 10 20
# 10
# 30

# %%
print("inside this quotation it considers as text")
# Out:
# inside this quotation it considers as text

# %%
print(var1)

print("var1")

print('var3')
# Out:
# 10
# var1
# var3

# %%
print('value of var1 is',var1)
print('value of var3 is',var3)
# Out:
# value of var1 is 10
# value of var3 is 30

# %%
var='ruthra'
print(var)
# Out:
# ruthra

# %%
type(var),type(var1)
# Out:
# (str, int)

# %%
xx=True
type(xx)
# Out:
# bool

# %%
ruthra='good boy'
type(ruthra)
# Out:
# str

# %%
ngeative=False

# %%
type(ngeative)
# Out:
# bool

# %%
float(var1)
# Out:
# 10.0

# %%
var1=float(10)

# %%
type(var1)
# Out:
# float

# %%
r="1561552"
type (r)
# Out:
# str

# %%
int (r),float(r)
# Out:
# (1561552, 1561552.0)

# %%
y="151.021"
type(y)
# Out:
# str

# %% [markdown]
# the above code containing** decimal** cannot be directly converted into int because it does not understand how to do it so we frist change it to flost and then int

# %%
int(float(y))
# Out:
# 151

# %% [markdown]
# collective data types

# %%
#list,tuple,set and dictionary

# %%
r=[1,2,2,3,4,5,96,'rocky']
type(r)
len(r)
# Out:
# 8

# %%
r1=[]
type(r1)
len(r1)
# Out:
# 0

# %%
r[0],r[-1]
# Out:
# (1, 'rocky')

# %% [markdown]
# negative value are used to find values from last and the position always starts with 0

# %%
r2=[9,8,5,84,684]

# %%
y=r+r2
y[-1]=555
y
# Out:
# [1, 2, 2, 3, 4, 5, 96, 'rocky', 9, 8, 5, 84, 555]

# %%
3 in y
# Out:
# True

# %%
y=tuple(y)
y
# Out:
# (1, 2, 2, 3, 4, 5, 96, 'rocky', 9, 8, 5, 84, 684)

# %%
ll=(1,5,47,687,3968)
ll
type(ll)
ll[0]=56565
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4a083402deb6> in <cell line: 4>()
#       2 ll
#       3 type(ll)
# ----> 4 ll[0]=56565
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# the above throws error bcoz tuple does not allow to replace the values so we change to list and replace it and finally convert to tuples as follows

# %%
l=list(ll)
l[2] = 49
l=tuple(l)
l
# Out:
# (1, 5, 49, 687, 3968)

# %%
# set

# %%
s1={2,5,7,10}
s1
type (s1)
# Out:
# set

# %%
s2={2,5,2,6,7,12,15}
s2
# Out:
# {2, 5, 6, 7, 12, 15}

# %%
s1.union(s2)
s1.intersection(s2)
s1.difference(s2)
s2.difference(s1)
# Out:
# {6, 12, 15}

# %%
# dictionary

# %%
d={'name':'ruthraa','mark':100}

# %%
len(d)
d.keys()
d.values()
d.items()
# Out:
# dict_items([('name', 'ruthraa'), ('mark', 100)])

# %%
d1={'a':15,'b':[3,6,5],3:{1:2,5:6}}
d1.keys()
d1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-7b04cf0f998e> in <cell line: 3>()
#       1 d1={'a':15,'b':[3,6,5],3:{1:2,5:6}}
#       2 d1.keys()
# ----> 3 d1[0]
#
# KeyError: 0

# %% [markdown]
# the above code tries to find the location in dictionary it is not possible instead we can do it by using keys as follows

# %%
d1['b'][1]

d1[3][5]
# Out:
# 6
